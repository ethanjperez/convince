# %%
import matplotlib.pyplot as plt
import numpy as np

f1_drop = [10 * i for i in range(-1, 11)]
bin_start = [i + 1 for i in f1_drop[:-1]]
acc = [0.9755916595458984, 0.3349056541919708, 0.2956521809101105, 0.31578946113586426, 0.33000001311302185, 0.2957746386528015, 0.2291666716337204, 0.2985074520111084, 0.21666666865348816, 0.25531914830207825, 0.25356125831604004]
num_samples = [35.55849075317383, 0.800000011920929, 0.43396225571632385, 0.28679245710372925, 0.37735849618911743, 0.2679245173931122, 0.18113207817077637, 0.2528301775455475, 0.22641509771347046, 0.1773584932088852, 1.3245283365249634]
num_samples = np.array(num_samples)
num_samples = num_samples / num_samples.sum()

# F1 drop vs. Acc
fig, ax = plt.subplots()
ax.set_xlabel('Judge F1 Drop with Oracle B')
ax.set_ylabel('Supervised B: Oracle Prediction Accuracy')
plt.title('Supervised B Accuracy by Oracle F1 Drop')
plt.hist(bin_start, bins=f1_drop, weights=acc)
plt.show()

# F1 drop vs. # Samples
fig, ax = plt.subplots()
ax.set_xlabel('Judge F1 Drop with Oracle B')
ax.set_ylabel('% of Samples')
plt.title('Supervised B Accuracy by % of Samples')
plt.hist(bin_start, bins=f1_drop, weights=num_samples)
plt.show()

# %%
num_samples
# Out:
# array([0.89148534, 0.02005676, 0.01087985, 0.00719016, 0.00946074,
#        0.00671712, 0.00454115, 0.00633869, 0.00567644, 0.00444655,
#        0.03320719])
